# %%
import pandas 
import pickle

# %%
# !wget https://rileypence-copy.s3.amazonaws.com/song_list_v7.pkl
# Out:
# --2020-06-10 20:52:25--  https://rileypence-copy.s3.amazonaws.com/song_list_v7.pkl
# Resolving rileypence-copy.s3.amazonaws.com (rileypence-copy.s3.amazonaws.com)... 52.216.78.244
# Connecting to rileypence-copy.s3.amazonaws.com (rileypence-copy.s3.amazonaws.com)|52.216.78.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145550648 (139M) [application/x-www-form-urlencoded]
# Saving to: ‘song_list_v7.pkl’
#
# song_list_v7.pkl    100%[===================>] 138.81M  9.78MB/s    in 22s
#
# 2020-06-10 20:52:47 (6.35 MB/s) - ‘song_list_v7.pkl’ saved [145550648/145550648]

# %%
df = pickle.load( open( "./data/song_list_v7.pkl", "rb" ) )

# %%
df.head()
# Out:
#                    songid  availability  year by_decade_and_quinquennial  \
# 0  5PS5dpaLogPzYU9hWiWyZb           1.0  2006                  2005-2010
# 1  41RpZW2lxAdnqDd2nMBzLQ           1.0  2009                  2005-2010
# 2  3GsS8jzoixpCnp4jDWCEvb           1.0  1993                      90-95
# 3  0kq75szR7uDEYrZkT2c4Ry           1.0  2018                  2015-2019
# 4  2HyFpkX9J7vv3OZNDaraHZ           1.0  2005                  2005-2010
#
#    index popularity  acousticness            artist  danceability  \
# 0      0          0      0.001300  Karkkiautomaatti         0.487
# 1      1         15      0.000045    Hudson Mohawke         0.662
# 2      2         17      0.002760        Kris Kross         0.859
# 3      3         21      0.348000     Jorge Negrete         0.361
# 4      4          1      0.340000         Tiger Lou         0.533
#
#    duration_ms  ...   key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
[genre.split(",") for genre in df["genres"]]
# Out:
# [["['finnish indie'", " 'suomi rock']"],
#  ["['bass music'",
#   " 'scottish electronic'",
#   " 'scottish hip hop'",
#   " 'uk experimental electronic'",
#   " 'wonky']"],
#  ["['hip hop'", " 'new jack swing'", " 'rap']"],
#  ["['bolero'", " 'mariachi'", " 'ranchera']"],
#  ["['swedish indie rock']"],
#  ["['semba']"],
#  ["['classic swedish pop'", " 'europop'", " 'swedish pop']"],
#  ["['ectofolk'",
#   " 'folk'",
#   " 'lilith'",
#   " 'new wave pop'",
#   " 'pop rock'",
#   " 'singer-songwriter'",
#   " 'traditional folk']"],
#  ["['brutal death metal'",
#   " 'death metal'",
#   " 'deathgrind'",
#   " 'groove metal'",
#   " 'technical death metal']"],
#  ["['christian metal'",
#   " 'christian rock'",
#   " 'dreamo'",
#   " 'post-hardcore'",
#   " 'progressive post-hardcore'",
#   " 'screamo']"],
#  ["['contemporary gospel'", " 'gospel']"],
#  ["['alternative americana'", " 'folk']"],
#  ["['alternative metal'",
#   " 'groove metal'",
#   " 'industrial metal'",
# ...
